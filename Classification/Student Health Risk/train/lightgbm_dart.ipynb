# %%
import joblib
import pandas as pd
from sklearn import set_config
from tempfile import TemporaryDirectory
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier
from lightgbm import LGBMClassifier
from sklearn.utils.class_weight import compute_sample_weight
import warnings

# %%
target_column = "health_condition"

# %%
X_train = pd.read_csv("../data/intermediate/train_features.csv")
X_valid = pd.read_csv("../data/intermediate/valid_features.csv")
X_test = pd.read_csv("../data/intermediate/test_features.csv")

y_train = pd.read_csv("../data/intermediate/train_labels.csv")
y_valid = pd.read_csv("../data/intermediate/valid_labels.csv")

X_train['diet_type'] = X_train['diet_type'].astype('category')
X_valid['diet_type'] = X_valid['diet_type'].astype('category')
X_test['diet_type'] = X_test['diet_type'].astype('category')

X_train['gender'] = X_train['gender'].astype('category')
X_valid['gender'] = X_valid['gender'].astype('category')
X_test['gender'] = X_test['gender'].astype('category')

X_train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 552070 entries, 0 to 552069
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   sleep_duration                491266 non-null  float64
#  1   heart_rate                    545802 non-null  float64
#  2   bmi                           541053 non-null  float64
#  3   calorie_expenditure           509705 non-null  float64
#  4   step_count                    540909 non-null  float64
#  5   exercise_duration             546550 non-null  float64
#  6   water_intake                  517224 non-null  float64
#  7   diet_type                     546580 non-null  category
#  8   stress_level                  485727 non-null  float64
#  9   sleep_quality                 505469 non-null  float64
#  10  physical_activity_level       522744 non-null  float64
#  11  smoking_alcohol               529184 non-null  float64
#  12  gender                        535022 non-null  category
#  13  calorie_expenditure_per_step  499392 non-null  float64
#  14  step_speed                    535492 non-null  float64
#  15  calorie_expenditure_per_min   504583 non-null  float64
#  16  calorie_expenditure_per_bmi   499529 non-null  float64
#  17  has_exercised                 552070 non-null  bool
# dtypes: bool(1), category(2), float64(15)
# memory usage: 64.8 MB

# %%
X = pd.concat([X_train, X_valid], axis=0)
y = pd.concat([y_train, y_valid], axis=0)

# %%
df_submission = pd.read_csv("../data/sample_submission.csv")
df_submission.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 295753 entries, 0 to 295752
# Data columns (total 2 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                295753 non-null  int64
#  1   health_condition  295753 non-null  str
# dtypes: int64(1), str(1)
# memory usage: 4.5 MB

# %%
train_sample_weight = compute_sample_weight(class_weight="balanced", y=y_train)
valid_sample_weight = compute_sample_weight(class_weight="balanced", y=y_valid)
y_sample_weight = compute_sample_weight(class_weight="balanced", y=y)

model = LGBMClassifier(boosting_type='dart', n_estimators=100, learning_rate=0.1, max_depth=8, objective='multiclass', early_stopping_round=100)
model.fit(X_train, y_train, sample_weight=train_sample_weight, eval_set=[(X_valid, y_valid)])

joblib.dump(model, '../models/lgbm_dart_80.pkl')
# Out:
# c:\Users\abhin\.pyenv\pyenv-win\versions\3.14.2\Lib\site-packages\sklearn\preprocessing\_label.py:103: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\abhin\.pyenv\pyenv-win\versions\3.14.2\Lib\site-packages\sklearn\preprocessing\_label.py:139: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# c:\Users\abhin\.pyenv\pyenv-win\versions\3.14.2\Lib\site-packages\sklearn\preprocessing\_label.py:139: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# c:\Users\abhin\.pyenv\pyenv-win\versions\3.14.2\Lib\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# c:\Users\abhin\.pyenv\pyenv-win\versions\3.14.2\Lib\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [1]	valid_0's multi_logloss: 0.941432
# [2]	valid_0's multi_logloss: 0.818818
# [3]	valid_0's multi_logloss: 0.720439
# [4]	valid_0's multi_logloss: 0.64018
# c:\Users\abhin\.pyenv\pyenv-win\versions\3.14.2\Lib\site-packages\lightgbm\callback.py:223: UserWarning: Early stopping is not available in dart mode
#   _log_warning('Early stopping is not available in dart mode')
# [5]	valid_0's multi_logloss: 0.573933
# [6]	valid_0's multi_logloss: 0.518727
# [7]	valid_0's multi_logloss: 0.47237
# [8]	valid_0's multi_logloss: 0.494523
# [9]	valid_0's multi_logloss: 0.451995
# [10]	valid_0's multi_logloss: 0.415916
# [11]	valid_0's multi_logloss: 0.3853
# [12]	valid_0's multi_logloss: 0.397525
# [13]	valid_0's multi_logloss: 0.369624
# [14]	valid_0's multi_logloss: 0.345772
# [15]	valid_0's multi_logloss: 0.325332
# [16]	valid_0's multi_logloss: 0.307759
# [17]	valid_0's multi_logloss: 0.292551
# [18]	valid_0's multi_logloss: 0.279442
# [19]	valid_0's multi_logloss: 0.268114
# [20]	valid_0's multi_logloss: 0.258415
# [21]	valid_0's multi_logloss: 0.261993
# [22]	valid_0's multi_logloss: 0.253101
# [23]	valid_0's multi_logloss: 0.245463
# [24]	valid_0's multi_logloss: 0.238694
# [25]	valid_0's multi_logloss: 0.23291
# [26]	valid_0's multi_logloss: 0.227854
# [27]	valid_0's multi_logloss: 0.223395
# [28]	valid_0's multi_logloss: 0.225734
# [29]	valid_0's multi_logloss: 0.221555
# [30]	valid_0's multi_logloss: 0.217831
# [31]	valid_0's multi_logloss: 0.219139
# [32]	valid_0's multi_logloss: 0.215735
# [33]	valid_0's multi_logloss: 0.212742
# [34]	valid_0's multi_logloss: 0.209995
# [35]	valid_0's multi_logloss: 0.212138
# [36]	valid_0's multi_logloss: 0.216013
# [37]	valid_0's multi_logloss: 0.212852
# [38]	valid_0's multi_logloss: 0.210118
# [39]	valid_0's multi_logloss: 0.207661
# [40]	valid_0's multi_logloss: 0.207656
# [41]	valid_0's multi_logloss: 0.209976
# [42]	valid_0's multi_logloss: 0.207532
# [43]	valid_0's multi_logloss: 0.209496
# [44]	valid_0's multi_logloss: 0.207154
# [45]	valid_0's multi_logloss: 0.205081
# [46]	valid_0's multi_logloss: 0.209051
# [47]	valid_0's multi_logloss: 0.206707
# [48]	valid_0's multi_logloss: 0.207254
# [49]	valid_0's multi_logloss: 0.209586
# [50]	valid_0's multi_logloss: 0.212086
# [51]	valid_0's multi_logloss: 0.209285
# [52]	valid_0's multi_logloss: 0.206903
# [53]	valid_0's multi_logloss: 0.209014
# [54]	valid_0's multi_logloss: 0.206643
# [55]	valid_0's multi_logloss: 0.204619
# [56]	valid_0's multi_logloss: 0.207084
# [57]	valid_0's multi_logloss: 0.204882
# [58]	valid_0's multi_logloss: 0.208104
# [59]	valid_0's multi_logloss: 0.211225
# [60]	valid_0's multi_logloss: 0.208463
# [61]	valid_0's multi_logloss: 0.211001
# [62]	valid_0's multi_logloss: 0.208206
# [63]	valid_0's multi_logloss: 0.205848
# [64]	valid_0's multi_logloss: 0.207968
# [65]	valid_0's multi_logloss: 0.209401
# [66]	valid_0's multi_logloss: 0.20686
# [67]	valid_0's multi_logloss: 0.204614
# [68]	valid_0's multi_logloss: 0.20268
# [69]	valid_0's multi_logloss: 0.204198
# [70]	valid_0's multi_logloss: 0.205123
# [71]	valid_0's multi_logloss: 0.207256
# [72]	valid_0's multi_logloss: 0.20499
# [73]	valid_0's multi_logloss: 0.202975
# [74]	valid_0's multi_logloss: 0.204051
# [75]	valid_0's multi_logloss: 0.20223
# [76]	valid_0's multi_logloss: 0.202457
# [77]	valid_0's multi_logloss: 0.203518
# [78]	valid_0's multi_logloss: 0.205239
# [79]	valid_0's multi_logloss: 0.20319
# [80]	valid_0's multi_logloss: 0.20142
# [81]	valid_0's multi_logloss: 0.202813
# [82]	valid_0's multi_logloss: 0.201042
# [83]	valid_0's multi_logloss: 0.202663
# [84]	valid_0's multi_logloss: 0.20394
# [85]	valid_0's multi_logloss: 0.20546
# [86]	valid_0's multi_logloss: 0.203403
# [87]	valid_0's multi_logloss: 0.201659
# [88]	valid_0's multi_logloss: 0.203184
# [89]	valid_0's multi_logloss: 0.204618
# [90]	valid_0's multi_logloss: 0.205965
# [91]	valid_0's multi_logloss: 0.207673
# [92]	valid_0's multi_logloss: 0.205292
# [93]	valid_0's multi_logloss: 0.203165
# [94]	valid_0's multi_logloss: 0.204227
# [95]	valid_0's multi_logloss: 0.205454
# [96]	valid_0's multi_logloss: 0.206637
# [97]	valid_0's multi_logloss: 0.204417
# [98]	valid_0's multi_logloss: 0.205896
# [99]	valid_0's multi_logloss: 0.203685
# [100]	valid_0's multi_logloss: 0.201783
# ['../models/lgbm_dart_80.pkl']

# %%
from sklearn.metrics import balanced_accuracy_score

y_pred = model.predict(X_valid)

val_score = balanced_accuracy_score(y_valid, y_pred, sample_weight=valid_sample_weight)
print("Validation Balanced Accuracy:", val_score)
# Out:
# Validation Balanced Accuracy: 0.9501159657815261

# %%
model = LGBMClassifier(boosting_type='dart', n_estimators=100, learning_rate=0.1, max_depth=8, objective='multiclass', enable_categorical=True)
model.fit(X, y, sample_weight=y_sample_weight)

joblib.dump(model, '../models/lgbm_dart_100.pkl')
# Out:
# c:\Users\abhin\.pyenv\pyenv-win\versions\3.14.2\Lib\site-packages\sklearn\preprocessing\_label.py:103: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\abhin\.pyenv\pyenv-win\versions\3.14.2\Lib\site-packages\sklearn\preprocessing\_label.py:139: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Warning] Unknown parameter: enable_categorical
# ['../models/lgbm_dart_100.pkl']

# %%
y_pred = model.predict(X_test)

df_submission[target_column] = y_pred
df_submission[target_column] = df_submission[target_column].replace({0:'unhealthy', 1:'at-risk', 2: 'fit'})

df_submission.to_csv('../results/lgbm_dart_baseline.csv', index=False)
df_submission
# Out:
#             id health_condition
# 0       690088        unhealthy
# 1       690089        unhealthy
# 2       690090          at-risk
# 3       690091          at-risk
# 4       690092        unhealthy
# ...        ...              ...
# 295748  985836              fit
# 295749  985837          at-risk
# 295750  985838        unhealthy
# 295751  985839          at-risk
# 295752  985840        unhealthy
#
# [295753 rows x 2 columns]
