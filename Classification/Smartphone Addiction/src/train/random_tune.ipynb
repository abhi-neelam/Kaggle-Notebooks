# %%
import joblib
import optuna
import copy
from optuna.samplers import RandomSampler, TPESampler
from optuna.visualization.matplotlib import plot_optimization_history, plot_param_importances, plot_slice, plot_parallel_coordinate
import numpy as np
import pandas as pd
from tabpfn import TabPFNClassifier, TabPFNRegressor
from xgboost import XGBClassifier, XGBRegressor
from lightgbm import LGBMClassifier, LGBMRegressor
from catboost import CatBoostClassifier, CatBoostRegressor
from sklearn.linear_model import SGDClassifier, SGDRegressor, LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.ensemble import AdaBoostClassifier, AdaBoostRegressor 
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.ensemble import ExtraTreesClassifier, ExtraTreesRegressor
from sklearn.ensemble import HistGradientBoostingClassifier, HistGradientBoostingRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.metrics import roc_auc_score
from fastparquet import write
from fastparquet import ParquetFile
from pathlib import Path
import datetime as dt
import time
import pytz
import json
import os

# %%
pst = pytz.timezone('America/Los_Angeles')
dt_str = dt.datetime.now(pst).strftime("%Y-%m-%d-%I_%M_%S_%p")
dt_str
# Out:
# '2026-09-11-06_59_57_PM'

# %%
oof_experiment_config = {
    "experiment": {
        "model": "xgboost",
        "type": "optuna",
        "num_trials": 80,
        "train_base_features": "baseline",
        "train_feature_groups": ["features", "target_encode", "freq_encode", "frac", "label_encode", "decimal", "combine_cats"],
        "description": "xgb + rand target + rand features + random sampler optuna tune",
    },

    "cv": {
        "strategy": "StratifiedKFold",
        "n_splits": 5,
        "shuffle": True,
        "random_state": 0
    },

    "features": {
        "class_sample_weight": False
    },

    "params": {
        "objective": "binary:logistic",
        "eval_metric": "auc",
        "enable_categorical": True,
        "early_stopping_rounds": 100,
        "device": "cuda",
        "n_jobs": -1,
        "verbosity": 0
    },
    
    "fit_params": {
    }
}
oof_experiment_config["experiment"]["id"] = f"{dt_str}_{oof_experiment_config["experiment"]["model"]}"
experiment_config = copy.deepcopy(oof_experiment_config)

# %%
def tune_params(trial):
    tree_method = trial.suggest_categorical("tree_method", ["hist", "approx"])
    booster = trial.suggest_categorical("booster", ["gbtree"])
    grow_policy = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])

    if grow_policy == "lossguide":
        max_depth = 0
        max_leaves = trial.suggest_int('max_leaves', 8, 1024)
    else:
        max_depth = trial.suggest_int('max_depth', 2, 15)
        max_leaves = 0

    trial_params = {
        "n_estimators": trial.suggest_int('n_estimators', 100, 2000, step=50),
        'max_depth': max_depth,
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.4, log=True),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 1.0),
        'colsample_bylevel': trial.suggest_float('colsample_bytree', 0.3, 1.0),
        "colsample_bynode": trial.suggest_float("colsample_bynode", 0.3, 1.0),
        "booster": booster,
        "lambda": trial.suggest_float("lambda", 1e-8, 50.0, log=True),
        "alpha": trial.suggest_float("alpha", 1e-8, 50.0, log=True),
        "gamma": trial.suggest_float("gamma", 1e-8, 20.0, log=True),
        "min_child_weight": trial.suggest_float('min_child_weight', 1, 30, log=True),
        "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
        "tree_method": tree_method,
        "grow_policy": grow_policy
    }

    if grow_policy == "lossguide":
        trial_params["max_leaves"] = max_leaves

    return trial_params

# %%
sampler = RandomSampler()

# %%
if os.environ.get('KAGGLE_KERNEL_RUN_TYPE'):
    data_path = "/kaggle/input/datasets/abhinavneelam/smartphone-addiction/dataset/data"
    experiments_path = "/kaggle/input/datasets/abhinavneelam/smartphone-addiction/dataset/experiments"
    output_path = "/kaggle/working/"
else:
    data_path = "../../data"
    experiments_path = "../../experiments"
    output_path = "../../"

# %%
ss = pd.read_csv(f"{data_path}/raw/sample_submission.csv")
target_column = ss.columns[-1]
target_column
# Out:
# 'addicted_label'

# %%
raw_train_df = pd.read_csv(f"{data_path}/raw/train.csv")
raw_train_id = raw_train_df["id"]
y = raw_train_df[target_column]

# %%
def make_model(config, optuna_params=None):
    name = config["experiment"]["model"]
    target = config["experiment"]["target"]
    params = config["params"]

    if optuna_params is None:
        optuna_params = {}

    model_dict = {
        "adaboost": (AdaBoostClassifier, AdaBoostRegressor),
        "gradientboost": (GradientBoostingClassifier, GradientBoostingRegressor),
        "catboost": (CatBoostClassifier, CatBoostRegressor), # TODO - fix missing col issue in catboost
        "xgboost": (XGBClassifier, XGBRegressor),
        "lightgbm": (LGBMClassifier, LGBMRegressor),
        "randomforest": (RandomForestClassifier, RandomForestRegressor),
        "extratrees": (ExtraTreesClassifier, ExtraTreesRegressor),
        "hgbc": (HistGradientBoostingClassifier, HistGradientBoostingRegressor),
        "knn": (KNeighborsClassifier, KNeighborsRegressor),
        "sgd": (SGDClassifier, SGDRegressor),
        "linear": (LogisticRegression, LinearRegression),
        "decisiontree": (DecisionTreeClassifier, DecisionTreeRegressor),
        "mlp": (MLPClassifier, MLPRegressor),
        "tabpfn": (TabPFNClassifier, TabPFNRegressor),
    }

    target_index = target == "regression"
    model_class = model_dict[name][target_index]

    return model_class(**params, **optuna_params)

# %%
def oof_fit(config, model, X_train, y_train, X_valid, y_valid):
    name = config["experiment"]["model"]
    no_eval_models = ["adaboost", "gradientboost", "randomforest", "extratrees", "knn", "sgd", "linear", "decisiontree", "mlp", "tabpfn"]
    fit_params = config["fit_params"]
    
    if "features" in config and "class_sample_weight" in config["features"] and config["features"]["class_sample_weight"]:
        train_sample_weight = compute_sample_weight(class_weight="balanced", y=y_train)
    else:
        train_sample_weight = None

    if name in no_eval_models:
        model.fit(X_train, y_train, sample_weight=train_sample_weight)
    elif name == "hgbc":
        model.fit(X_train, y_train, X_val=X_valid, y_val=y_valid, sample_weight=train_sample_weight)
    elif name == "lightgbm":
        model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)], sample_weight=train_sample_weight, **fit_params)
    else:
        model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)], sample_weight=train_sample_weight, verbose=False)

# %%
def predict(config, model, X_feat):
    task = config["experiment"]["target"]
    if task == "classification":
        return model.predict_proba(X_feat)[:, 1]
    else:
        return model.predict(X_feat)

# %%
experiment_path = Path(output_path) / "experiments" / f"{dt_str}_optuna_{experiment_config["experiment"]["model"]}"
experiment_path.mkdir(parents=True, exist_ok=True)

# %%
def update_config(model, experiment_config):
    config = copy.deepcopy(experiment_config)
    params = config["params"]
    tree_param_keys = ["n_estimators", "max_iter"]

    best_iter = None
    if hasattr(model, "best_iteration_"):
        best_iter = model.best_iteration_
    elif hasattr(model, "best_iteration"):
        best_iter = model.best_iteration
    elif hasattr(model, "n_iter_"):
        n_iter_val = model.n_iter_
        
        if isinstance(n_iter_val, np.ndarray):
            if n_iter_val.size == 1:
                best_iter = n_iter_val.item()
            else:
                best_iter = int(n_iter_val.max())
        else:
            best_iter = int(n_iter_val)

    if best_iter is not None:
        for key in tree_param_keys:
            if key in params:
                params[key] = best_iter

    training_only_params = [
        "early_stopping_rounds",
        "early_stopping",
        "n_iter_no_change",
        "validation_fraction",
        "eval_set",
    ]

    for key in training_only_params:
        if key in params:
            del params[key]

    return config

# %%
cv_config = experiment_config["cv"]
exp_config = experiment_config["experiment"]

def objective(trial):
    X_base = ParquetFile(f"{data_path}/{exp_config["train_base_features"]}/train.parq").to_pandas()
    X_test_base = ParquetFile(f"{data_path}/{exp_config["train_base_features"]}/test.parq").to_pandas()
    X_dfs = [X_base]
    X_test_dfs = [X_test_base]

    target = trial.suggest_categorical(f"target", ["classification", "regression"])
    oof_experiment_config["experiment"]["target"] = target

    fg_trial = []
    
    for fg in exp_config["train_feature_groups"]:
        include_fg = trial.suggest_categorical(f"include_{fg}", [True, False])
        if include_fg:
            fg_trial.append(fg)

            df = ParquetFile(f"{data_path}/{fg}/train.parq").to_pandas()
            X_dfs.append(df)

            df = ParquetFile(f"{data_path}/{fg}/test.parq").to_pandas()
            X_test_dfs.append(df)

    X = pd.concat(X_dfs, axis=1)
    X_test = pd.concat(X_test_dfs, axis=1)
    kf = StratifiedKFold(n_splits=cv_config["n_splits"], random_state=cv_config["random_state"], shuffle=cv_config["shuffle"])
    
    train_index, valid_index = next(kf.split(X, y))
    valid_ids = raw_train_id.iloc[valid_index].reset_index(drop=True)

    X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]

    local_dt_str = dt.datetime.now(pst).strftime("%Y-%m-%d-%I_%M_%S_%p")

    start_time = time.time()
    trial_params = tune_params(trial)
    model = make_model(oof_experiment_config, trial_params)

    oof_fit(
        oof_experiment_config,
        model,
        X_train,
        y_train,
        X_valid,
        y_valid
    )
    elapsed = time.time() - start_time
    
    y_pred = predict(oof_experiment_config, model, X_valid)
    y_pred_df = pd.concat([valid_ids, pd.Series(y_pred, name=target_column)], axis=1)
    valid_score = roc_auc_score(y_valid, y_pred)
    fold_scores = [round(valid_score, 5)]

    metrics = {
        "experiment": local_dt_str + f"_{experiment_config["experiment"]["model"]}",
        "model": f"{experiment_config["experiment"]["model"]}",
        "train_base_features": f"{experiment_config["experiment"]["train_base_features"]}",
        "train_feature_groups": fg_trial,
        "cv": {
            "strategy": f"{experiment_config["cv"]["strategy"]}",
            "n_splits": experiment_config["cv"]["n_splits"],
            "random_state": experiment_config["cv"]["random_state"],
            "fold_scores": fold_scores,
            "mean": round(sum(fold_scores) / len(fold_scores), 5),
            "std": 0.0
        },
        "primary_metric": {
            "name": "auc",
            "value": round(valid_score, 5)
        },
        "training": {
            "duration_seconds": round(elapsed, 2)
        }
    }

    tune_experiment_config = copy.deepcopy(oof_experiment_config)
    tune_experiment_config["params"] = oof_experiment_config["params"] | trial_params
    tune_experiment_config["experiment"]["train_feature_groups"] = fg_trial

    full_config = update_config(model, tune_experiment_config)

    model = make_model(full_config)
    model.fit(X, y)

    y_pred = predict(full_config, model, X_test)
    ss[target_column] = y_pred

    model_experiment_path = experiment_path / f"{experiment_config["experiment"]["model"]}_trial_{trial.number}"
    model_experiment_path.mkdir(parents=True, exist_ok=True)

    with open(model_experiment_path / "oof_config.json", "w") as f:
        json.dump(tune_experiment_config, f, indent=4)

    with open(model_experiment_path / "full_config.json", "w") as f:
        json.dump(full_config, f, indent=4)

    with open(model_experiment_path / "metrics.json", "w") as f:
        json.dump(metrics, f, indent=4)

    y_pred_df.to_csv(model_experiment_path / "oof.csv", index=False)
    joblib.dump(model, model_experiment_path / f"{experiment_config["experiment"]["model"]}.pkl")

    ss.to_csv(model_experiment_path / "submission.csv", index=False)

    return valid_score

# %%
study = optuna.create_study(sampler=sampler, direction='maximize')
study.optimize(objective, n_trials=oof_experiment_config['experiment']['num_trials'])
# Out:
# [I 2026-09-12 01:59:58,309] A new study created in memory with name: no-name-c01bd721-93a3-4f6f-aead-211573f718a6
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 02

# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 03:10:26,768] Trial 22 finished with value: 0.967083764169816 and parameters: {'target': 'regression', 'include_features': True, 'include_target_encode': True, 'include_freq_encode': True, 'include_frac': True, 'include_label_encode': True, 'include_decimal': True, 'include_combine_cats': False, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 655, 'n_estimators': 2000, 'learning_rate': 0.03503165028418065, 'subsample': 0.6677323243670472, 'colsample_bytree': 0.5686904313881338, 'colsample_bynode': 0.6467583373474516, 'lambda': 0.0005601638186036749, 'alpha': 0.0003257676803153979, 'gamma': 0.00013815664188477825, 'min_child_weight': 17.043465951821776, 'max_bin': 112}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 03:11:45,030] Trial 23 finished with value: 0.9617090983570526 and parameters: {'target': 'regression', 'include_features': False, 'include_target_encode': False, 'include_freq_encode': True, 'include_frac': True, 'include_label_encode': True, 'include_decimal': False, 'include_combine_cats': False, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 8, 'n_estimators': 1450, 'learning_rate': 0.2712421323971539, 'subsample': 0.6654055820983291, 'colsample_bytree': 0.7821046895660603, 'colsample_bynode': 0.8122082261151096, 'lambda': 1.5142914488547803e-06, 'alpha': 0.31240855835069614, 'gamma': 1.6297186068634093e-06, 'min_child_weight': 17.85162347715255, 'max_bin': 102}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 03:18:34,745] Trial 24 finished with value: 0.943210836486589 and parameters: {'target': 'classification', 'include_features': False, 'include_target_encode': False, 'include_freq_encode': True, 'include_frac': True, 'include_label_encode': False, 'include_decimal': False, 'include_combine_cats': True, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 2, 'n_estimators': 1400, 'learning_rate': 0.028942202840755944, 'subsample': 0.7936524600410428, 'colsample_bytree': 0.7413996698827614, 'colsample_bynode': 0.9178170356031305, 'lambda': 1.207044437286201e-07, 'alpha': 7.805387072669635e-08, 'gamma': 0.0002738166328968193, 'min_child_weight': 27.846066646975157, 'max_bin': 82}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 03:21:04,879] Trial 25 finished with value: 0.9590052725988609 and parameters: {'target': 'classification', 'include_features': False, 'include_target_encode': True, 'include_freq_encode': False, 'include_frac': True, 'include_label_encode': True, 'include_decimal': False, 'include_combine_cats': True, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 2, 'n_estimators': 400, 'learning_rate': 0.14287139090364898, 'subsample': 0.7283885435108906, 'colsample_bytree': 0.32815626651031016, 'colsample_bynode': 0.6541103256483827, 'lambda': 4.906379866624605e-05, 'alpha': 0.01291942638156258, 'gamma': 0.03923188167017035, 'min_child_weight': 9.187750252813048, 'max_bin': 32}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 03:21:20,506] Trial 26 finished with value: 0.9650665388955099 and parameters: {'target': 'classification', 'include_features': True, 'include_target_encode': True, 'include_freq_encode': False, 'include_frac': False, 'include_label_encode': True, 'include_decimal': False, 'include_combine_cats': False, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 8, 'n_estimators': 950, 'learning_rate': 0.24361454677195746, 'subsample': 0.42855587184539723, 'colsample_bytree': 0.997588391357789, 'colsample_bynode': 0.4270833244252725, 'lambda': 4.343544619637469, 'alpha': 0.0002667107730975671, 'gamma': 0.0019348570710381588, 'min_child_weight': 1.2895597885119567, 'max_bin': 212}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 03:24:50,103] Trial 27 finished with value: 0.9664326936896225 and parameters: {'target': 'regression', 'include_features': False, 'include_target_encode': True, 'include_freq_encode': True, 'include_frac': False, 'include_label_encode': False, 'include_decimal': True, 'include_combine_cats': False, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 600, 'n_estimators': 700, 'learning_rate': 0.01686325189997827, 'subsample': 0.41467052324686166, 'colsample_bytree': 0.7888340651488932, 'colsample_bynode': 0.4923075845177264, 'lambda': 5.378642605730575, 'alpha': 0.0839913206450203, 'gamma': 2.486829172448123e-07, 'min_child_weight': 20.387308314171626, 'max_bin': 232}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 03:27:14,443] Trial 28 finished with value: 0.9653412142038555 and parameters: {'target': 'regression', 'include_features': True, 'include_target_encode': True, 'include_freq_encode': True, 'include_frac': True, 'include_label_encode': False, 'include_decimal': True, 'include_combine_cats': False, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 358, 'n_estimators': 1050, 'learning_rate': 0.1017930510087393, 'subsample': 0.4441061007797398, 'colsample_bytree': 0.4135364406238752, 'colsample_bynode': 0.9994349597623755, 'lambda': 0.0005373737067416907, 'alpha': 6.681446051496538e-07, 'gamma': 0.00575536353068093, 'min_child_weight': 2.5463783574580434, 'max_bin': 142}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 03:28:11,416] Trial 29 finished with value: 0.9452120117132035 and parameters: {'target': 'classification', 'include_features': False, 'include_target_encode': False, 'include_freq_encode': False, 'include_frac': True, 'include_label_encode': False, 'include_decimal': False, 'include_combine_cats': False, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 82, 'n_estimators': 750, 'learning_rate': 0.3250685377757162, 'subsample': 0.5092291964854474, 'colsample_bytree': 0.6050485786858595, 'colsample_bynode': 0.38477073570060016, 'lambda': 2.4321411879107023e-06, 'alpha': 0.05259656097572884, 'gamma': 0.0012536929925881816, 'min_child_weight': 9.240350160110511, 'max_bin': 52}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 03
. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 03:37:26,710] Trial 38 finished with value: 0.9665359633992541 and parameters: {'target': 'regression', 'include_features': True, 'include_target_encode': True, 'include_freq_encode': False, 'include_frac': False, 'include_label_encode': True, 'include_decimal': True, 'include_combine_cats': False, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 6, 'n_estimators': 200, 'learning_rate': 0.19959638835881355, 'subsample': 0.8954606333829416, 'colsample_bytree': 0.9041395322331793, 'colsample_bynode': 0.5915441617081267, 'lambda': 2.553383250596589e-08, 'alpha': 1.9683474486038305e-08, 'gamma': 0.06232360046860375, 'min_child_weight': 1.6387222324221888, 'max_bin': 182}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 03:46:46,940] Trial 39 finished with value: 0.9643352265496048 and parameters: {'target': 'classification', 'include_features': True, 'include_target_encode': False, 'include_freq_encode': True, 'include_frac': True, 'include_label_encode': True, 'include_decimal': True, 'include_combine_cats': True, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 561, 'n_estimators': 1950, 'learning_rate': 0.010542704463468488, 'subsample': 0.7868846069187858, 'colsample_bytree': 0.7452541083453518, 'colsample_bynode': 0.7306339820491206, 'lambda': 34.00796484953219, 'alpha': 3.831159456332053e-06, 'gamma': 1.290682029987608e-06, 'min_child_weight': 1.1954014791007879, 'max_bin': 162}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 03:47:04,183] Trial 40 finished with value: 0.9479316641189857 and parameters: {'target': 'classification', 'include_features': False, 'include_target_encode': False, 'include_freq_encode': False, 'include_frac': False, 'include_label_encode': True, 'include_decimal': True, 'include_combine_cats': False, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 3, 'n_estimators': 1450, 'learning_rate': 0.18994634778791103, 'subsample': 0.47696571383924763, 'colsample_bytree': 0.7909315492276294, 'colsample_bynode': 0.6536032824773916, 'lambda': 3.783977309693278e-05, 'alpha': 0.0002947651880089616, 'gamma': 0.001070178833506164, 'min_child_weight': 3.3972966939015414, 'max_bin': 42}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 04:06:00,010] Trial 41 finished with value: 0.9641945373864769 and parameters: {'target': 'regression', 'include_features': True, 'include_target_encode': False, 'include_freq_encode': True, 'include_frac': True, 'include_label_encode': True, 'include_decimal': False, 'include_combine_cats': False, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 13, 'n_estimators': 1600, 'learning_rate': 0.011629008272366547, 'subsample': 0.7066245049276385, 'colsample_bytree': 0.9040313960380548, 'colsample_bynode': 0.9886570148070792, 'lambda': 2.468525255667938e-08, 'alpha': 0.00044697634864696956, 'gamma': 3.131220408688642e-06, 'min_child_weight': 3.2291718432950423, 'max_bin': 112}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 04:08:07,852] Trial 42 finished with value: 0.9655790934477434 and parameters: {'target': 'classification', 'include_features': True, 'include_target_encode': True, 'include_freq_encode': True, 'include_frac': True, 'include_label_encode': True, 'include_decimal': True, 'include_combine_cats': True, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 417, 'n_estimators': 450, 'learning_rate': 0.09556792842325705, 'subsample': 0.4431766397691438, 'colsample_bytree': 0.8736740301769534, 'colsample_bynode': 0.7426892736539472, 'lambda': 1.7475784680858757e-05, 'alpha': 0.211681512941671, 'gamma': 3.6113478955019535e-07, 'min_child_weight': 2.3585940126211455, 'max_bin': 102}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 04:17:33,360] Trial 43 finished with value: 0.9582079576382055 and parameters: {'target': 'classification', 'include_features': False, 'include_target_encode': False, 'include_freq_encode': True, 'include_frac': True, 'include_label_encode': False, 'include_decimal': True, 'include_combine_cats': False, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 851, 'n_estimators': 1500, 'learning_rate': 0.09201688706578635, 'subsample': 0.9116927019470523, 'colsample_bytree': 0.4500523410971065, 'colsample_bynode': 0.4393728904926276, 'lambda': 4.189204206564066e-08, 'alpha': 3.018297076799068e-05, 'gamma': 2.6180718195707807e-08, 'min_child_weight': 2.8711719346901567, 'max_bin': 172}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 04:26:28,321] Trial 44 finished with value: 0.9376788411843746 and parameters: {'target': 'classification', 'include_features': False, 'include_target_encode': False, 'include_freq_encode': True, 'include_frac': False, 'include_label_encode': True, 'include_decimal': True, 'include_combine_cats': True, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 2, 'n_estimators': 1450, 'learning_rate': 0.015691655127545827, 'subsample': 0.7645972181772902, 'colsample_bytree': 0.8874092903032775, 'colsample_bynode': 0.5424723558984821, 'lambda': 2.5242977278867995e-08, 'alpha': 0.03169401274123682, 'gamma': 0.0019274643946206366, 'min_child_weight': 2.5121290260919875, 'max_bin': 62}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 04:27:45,331] Trial 45 finished with value: 0.9651446554790561 and parameters: {'target': 'regression', 'include_features': False, 'include_target_encode': True, 'include_freq_encode': False, 'include_frac': False, 'include_label_encode': False, 'include_decimal': True, 'include_combine_cats': False, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 14, 'n_estimators': 1400, 'learning_rate': 0.09791356199702556, 'subsample': 0.9311482120659118, 'colsample_bytree': 0.8998874106720947, 'colsample_bynode': 0.8257698961379012, 'lambda': 0.041084337830394266, 'alpha': 0.0007512470056664086, 'gamma': 2.9405281069313536e-07, 'min_child_weight': 2.212612058661955, 'max_bin': 152}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# ...
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 05:23:20,304] Trial 65 finished with value: 0.9558298781513814 and parameters: {'target': 'regression', 'include_features': False, 'include_target_encode': False, 'include_freq_encode': False, 'include_frac': False, 'include_label_encode': False, 'include_decimal': False, 'include_combine_cats': True, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 696, 'n_estimators': 1650, 'learning_rate': 0.17495084418039708, 'subsample': 0.8304776271173215, 'colsample_bytree': 0.8611692459607485, 'colsample_bynode': 0.6113587077244909, 'lambda': 22.31708562527728, 'alpha': 0.0008341077221537926, 'gamma': 0.003338722930136782, 'min_child_weight': 15.07923831889449, 'max_bin': 132}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 05:28:51,702] Trial 66 finished with value: 0.9665498490919631 and parameters: {'target': 'classification', 'include_features': False, 'include_target_encode': True, 'include_freq_encode': True, 'include_frac': True, 'include_label_encode': False, 'include_decimal': False, 'include_combine_cats': False, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 900, 'n_estimators': 1750, 'learning_rate': 0.026419500821432254, 'subsample': 0.692964388214347, 'colsample_bytree': 0.7384828251280778, 'colsample_bynode': 0.8896524218793509, 'lambda': 8.279802210668318e-08, 'alpha': 0.00016991061483362737, 'gamma': 6.218721241325758e-08, 'min_child_weight': 1.1376444781941921, 'max_bin': 172}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 05:30:47,642] Trial 67 finished with value: 0.9663909655700089 and parameters: {'target': 'regression', 'include_features': True, 'include_target_encode': True, 'include_freq_encode': False, 'include_frac': True, 'include_label_encode': True, 'include_decimal': True, 'include_combine_cats': False, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 373, 'n_estimators': 150, 'learning_rate': 0.041712155090526726, 'subsample': 0.9545279545150128, 'colsample_bytree': 0.6555229332501966, 'colsample_bynode': 0.6890829059208555, 'lambda': 0.5907003405892988, 'alpha': 1.1538164148424521, 'gamma': 2.7386847016158464e-08, 'min_child_weight': 2.365868503875849, 'max_bin': 172}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 05:34:25,073] Trial 68 finished with value: 0.9532792045164127 and parameters: {'target': 'classification', 'include_features': False, 'include_target_encode': False, 'include_freq_encode': False, 'include_frac': False, 'include_label_encode': False, 'include_decimal': True, 'include_combine_cats': False, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 3, 'n_estimators': 1150, 'learning_rate': 0.1610763973632019, 'subsample': 0.4615309416490072, 'colsample_bytree': 0.9852030950850135, 'colsample_bynode': 0.9298337143937137, 'lambda': 5.335795238445598e-06, 'alpha': 1.2260279267638545e-08, 'gamma': 15.550966938962862, 'min_child_weight': 5.422822006743733, 'max_bin': 192}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 05:38:19,114] Trial 69 finished with value: 0.9637921442023016 and parameters: {'target': 'classification', 'include_features': False, 'include_target_encode': False, 'include_freq_encode': True, 'include_frac': True, 'include_label_encode': False, 'include_decimal': False, 'include_combine_cats': False, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 665, 'n_estimators': 750, 'learning_rate': 0.028958782452767014, 'subsample': 0.8306386240051621, 'colsample_bytree': 0.9873309703577395, 'colsample_bynode': 0.47941199936454415, 'lambda': 0.015758484216648078, 'alpha': 0.0007611612030772788, 'gamma': 1.0653659708465766e-08, 'min_child_weight': 3.914132269477626, 'max_bin': 242}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 05:43:20,496] Trial 70 finished with value: 0.9606079800639727 and parameters: {'target': 'regression', 'include_features': False, 'include_target_encode': False, 'include_freq_encode': True, 'include_frac': False, 'include_label_encode': True, 'include_decimal': True, 'include_combine_cats': False, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 489, 'n_estimators': 2000, 'learning_rate': 0.05829644021673787, 'subsample': 0.6115001174134929, 'colsample_bytree': 0.3952497486599916, 'colsample_bynode': 0.5255459542430071, 'lambda': 0.885678407753553, 'alpha': 4.833302632030923, 'gamma': 4.102163992046725e-08, 'min_child_weight': 1.2135915556485042, 'max_bin': 162}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 05:43:43,220] Trial 71 finished with value: 0.9642051840948704 and parameters: {'target': 'regression', 'include_features': False, 'include_target_encode': True, 'include_freq_encode': False, 'include_frac': True, 'include_label_encode': True, 'include_decimal': True, 'include_combine_cats': False, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 7, 'n_estimators': 550, 'learning_rate': 0.172622248398531, 'subsample': 0.47061838492634744, 'colsample_bytree': 0.3170185045531998, 'colsample_bynode': 0.5390221573509758, 'lambda': 0.17486203108354353, 'alpha': 0.24951422234768939, 'gamma': 5.812951012964942e-05, 'min_child_weight': 1.426468031187311, 'max_bin': 122}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 05:48:46,909] Trial 72 finished with value: 0.9574787814844083 and parameters: {'target': 'regression', 'include_features': True, 'include_target_encode': False, 'include_freq_encode': True, 'include_frac': False, 'include_label_encode': True, 'include_decimal': False, 'include_combine_cats': False, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 939, 'n_estimators': 1000, 'learning_rate': 0.061541126784366885, 'subsample': 0.4411163626228878, 'colsample_bytree': 0.761728628706665, 'colsample_bynode': 0.3422302036399965, 'lambda': 1.551333389315568e-08, 'alpha': 0.6843951971103907, 'gamma': 6.393323891156635e-05, 'min_child_weight': 4.303468429698665, 'max_bin': 62}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 05:51:20,144] Trial 73 finished with value: 0.9666870128213556 and parameters: {'target': 'regression', 'include_features': False, 'include_target_encode': True, 'include_freq_encode': True, 'include_frac': True, 'include_label_encode': True, 'include_decimal': False, 'include_combine_cats': True, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 14, 'n_estimators': 900, 'learning_rate': 0.028810112360415037, 'subsample': 0.5876268561229762, 'colsample_bytree': 0.4007731098676434, 'colsample_bynode': 0.6049326316185946, 'lambda': 8.353107454954756e-07, 'alpha': 0.00037204174451339547, 'gamma': 2.8332264992722854e-07, 'min_child_weight': 8.95294146503593, 'max_bin': 122}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 05:51:40,245] Trial 74 finished with value: 0.9645754790865595 and parameters: {'target': 'classification', 'include_features': False, 'include_target_encode': True, 'include_freq_encode': False, 'include_frac': False, 'include_label_encode': False, 'include_decimal': True, 'include_combine_cats': True, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 3, 'n_estimators': 1800, 'learning_rate': 0.07333097164398708, 'subsample': 0.8180453959899805, 'colsample_bytree': 0.39060336272653057, 'colsample_bynode': 0.7029876570934053, 'lambda': 0.0002355144220958973, 'alpha': 0.0005297587932130312, 'gamma': 0.050192029099541575, 'min_child_weight': 5.108649003129822, 'max_bin': 42}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 05:52:35,290] Trial 75 finished with value: 0.9660977408222674 and parameters: {'target': 'regression', 'include_features': True, 'include_target_encode': True, 'include_freq_encode': True, 'include_frac': False, 'include_label_encode': False, 'include_decimal': True, 'include_combine_cats': False, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 15, 'n_estimators': 350, 'learning_rate': 0.0194119790779813, 'subsample': 0.8477746190079833, 'colsample_bytree': 0.5710352301689736, 'colsample_bynode': 0.9416697134473733, 'lambda': 0.00023419539548170525, 'alpha': 0.012695513427352227, 'gamma': 5.772789249067928, 'min_child_weight': 6.051976596926806, 'max_bin': 42}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 05:55:26,138] Trial 76 finished with value: 0.9660844474379466 and parameters: {'target': 'classification', 'include_features': True, 'include_target_encode': True, 'include_freq_encode': False, 'include_frac': False, 'include_label_encode': True, 'include_decimal': False, 'include_combine_cats': False, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 955, 'n_estimators': 200, 'learning_rate': 0.07438743409087822, 'subsample': 0.958982663876377, 'colsample_bytree': 0.4872237163493396, 'colsample_bynode': 0.38230806225539776, 'lambda': 9.73580434643656e-07, 'alpha': 9.005525394739575e-05, 'gamma': 0.09970259352015617, 'min_child_weight': 1.3844093846787355, 'max_bin': 142}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 06:03:00,117] Trial 77 finished with value: 0.9546972367212716 and parameters: {'target': 'classification', 'include_features': False, 'include_target_encode': False, 'include_freq_encode': False, 'include_frac': False, 'include_label_encode': True, 'include_decimal': False, 'include_combine_cats': True, 'tree_method': 'approx', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 791, 'n_estimators': 1950, 'learning_rate': 0.019721463179092093, 'subsample': 0.41787019380754925, 'colsample_bytree': 0.3859260755180858, 'colsample_bynode': 0.9896564397064802, 'lambda': 0.0001940483235316526, 'alpha': 6.49235729899045e-06, 'gamma': 3.014070328028986, 'min_child_weight': 7.305489897051247, 'max_bin': 92}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 06:04:20,620] Trial 78 finished with value: 0.9590796573477832 and parameters: {'target': 'classification', 'include_features': True, 'include_target_encode': False, 'include_freq_encode': True, 'include_frac': False, 'include_label_encode': True, 'include_decimal': False, 'include_combine_cats': True, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'lossguide', 'max_leaves': 513, 'n_estimators': 1850, 'learning_rate': 0.08959249182983614, 'subsample': 0.8768794016181773, 'colsample_bytree': 0.597963744485982, 'colsample_bynode': 0.405193332082961, 'lambda': 8.005217149940785e-05, 'alpha': 0.010163948805154907, 'gamma': 2.1342467312367788e-08, 'min_child_weight': 3.9009012784858696, 'max_bin': 52}. Best is trial 22 with value: 0.967083764169816.
# /tmp/ipykernel_44/1823986264.py:26: UserWarning: The distribution is specified by [32, 256] and step=10, but the range is not divisible by `step`. It will be replaced with [32, 252].
#   "max_bin": trial.suggest_int('max_bin', 32, 256, step=10),
# [I 2026-09-12 06:04:39,436] Trial 79 finished with value: 0.9648916885458904 and parameters: {'target': 'classification', 'include_features': True, 'include_target_encode': True, 'include_freq_encode': True, 'include_frac': False, 'include_label_encode': True, 'include_decimal': False, 'include_combine_cats': False, 'tree_method': 'hist', 'booster': 'gbtree', 'grow_policy': 'depthwise', 'max_depth': 12, 'n_estimators': 950, 'learning_rate': 0.34450324982546054, 'subsample': 0.8577908483356708, 'colsample_bytree': 0.9403724634064801, 'colsample_bynode': 0.9421184299147416, 'lambda': 6.304197337824296e-08, 'alpha': 0.0630738171026371, 'gamma': 0.007811955976279649, 'min_child_weight': 28.87837989263513, 'max_bin': 82}. Best is trial 22 with value: 0.967083764169816.

# %%
trial_df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
trial_df.to_csv(experiment_path / "optuna_trials.csv", index=False)
trial_df
# Out:
#     number     value  params_alpha params_booster  params_colsample_bynode  \
# 0        0  0.961875  3.766756e-04         gbtree                 0.943705
# 1        1  0.960969  4.271080e-07         gbtree                 0.582924
# 2        2  0.966111  1.174344e-08         gbtree                 0.457632
# 3        3  0.965791  3.282346e+01         gbtree                 0.643303
# 4        4  0.961866  4.880129e-01         gbtree                 0.311852
# ..     ...       ...           ...            ...                      ...
# 75      75  0.966098  1.269551e-02         gbtree                 0.941670
# 76      76  0.966084  9.005525e-05         gbtree                 0.382308
# 77      77  0.954697  6.492357e-06         gbtree                 0.989656
# 78      78  0.959080  1.016395e-02         gbtree                 0.405193
# 79      79  0.964892  6.307382e-02         gbtree                 0.942118
#
#     params_colsample_bytree  params_gamma params_grow_policy  \
# 0                  0.746721  5.851312e-07          lossguide
# 1                  0.847426  2.237679e-04          depthwise
# 2                  0.783736  2.798295e-06          lossguide
# 3                  0.505717  5.508428e-08          depthwise
# 4                  0.450322  1.208049e-01          depthwise
# ..                      ...           ...                ...
# 75                 0.571035  5.772789e+00          depthwise
# 76                 0.487224  9.970259e-02          lossguide
# 77                 0.385926  3.014070e+00          lossguide
# 78                 0.597964  2.134247e-08          lossguide
# 79                 0.940372  7.811956e-03          depthwise
#
#     params_include_combine_cats  params_include_decimal  ...  \
# 0                          True                   False  ...
# 1                         False                    True  ...
# 2                          True                    True  ...
# 3                          True                   False  ...
# 4                         False                   False  ...
# ..                          ...                     ...  ...
# 75                        False                    True  ...
# 76                        False                   False  ...
# 77                         True                   False  ...
# 78                         True                   False  ...
# 79                        False                   False  ...
#
#     params_learning_rate  params_max_bin  params_max_depth  params_max_leaves  \
# 0               0.073480             192               NaN              203.0
# 1               0.020801             252               3.0                NaN
# 2               0.090515              32               NaN              653.0
# 3               0.021947             222              14.0                NaN
# 4               0.035170             112              15.0                NaN
# ..                   ...             ...               ...                ...
# 75              0.019412              42              15.0                NaN
# 76              0.074387             142               NaN              955.0
# 77              0.019721              92               NaN              791.0
# 78              0.089592              52               NaN              513.0
# 79              0.344503              82              12.0                NaN
#
#     params_min_child_weight  params_n_estimators  params_subsample  \
# 0                  2.388539                  300          0.867733
# 1                  3.635990                  550          0.653802
# 2                  4.317162                  850          0.956543
# 3                 24.295641                 1200          0.470434
# 4                  1.478133                  150          0.411160
# ..                      ...                  ...               ...
# 75                 6.051977                  350          0.847775
# 76                 1.384409                  200          0.958983
# 77                 7.305490                 1950          0.417870
# 78                 3.900901                 1850          0.876879
# 79                28.878380                  950          0.857791
#
#      params_target  params_tree_method     state
# 0       regression              approx  COMPLETE
# 1       regression              approx  COMPLETE
# 2   classification                hist  COMPLETE
# 3   classification                hist  COMPLETE
# 4   classification              approx  COMPLETE
# ..             ...                 ...       ...
# 75      regression                hist  COMPLETE
# 76  classification              approx  COMPLETE
# 77  classification              approx  COMPLETE
# 78  classification                hist  COMPLETE
# 79  classification                hist  COMPLETE
#
# [80 rows x 26 columns]

# %%
study.best_trial.params
# Out:
# {'target': 'regression',
#  'include_features': True,
#  'include_target_encode': True,
#  'include_freq_encode': True,
#  'include_frac': True,
#  'include_label_encode': True,
#  'include_decimal': True,
#  'include_combine_cats': False,
#  'tree_method': 'approx',
#  'booster': 'gbtree',
#  'grow_policy': 'lossguide',
#  'max_leaves': 655,
#  'n_estimators': 2000,
#  'learning_rate': 0.03503165028418065,
#  'subsample': 0.6677323243670472,
#  'colsample_bytree': 0.5686904313881338,
#  'colsample_bynode': 0.6467583373474516,
#  'lambda': 0.0005601638186036749,
#  'alpha': 0.0003257676803153979,
#  'gamma': 0.00013815664188477825,
#  'min_child_weight': 17.043465951821776,
#  'max_bin': 112}

# %%
plot_optimization_history(study)
# Out:
# /tmp/ipykernel_44/3324289224.py:1: ExperimentalWarning: optuna.visualization.matplotlib._optimization_history.plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   plot_optimization_history(study)
# <Axes: title={'center': 'Optimization History Plot'}, xlabel='Trial', ylabel='Objective Value'>

# %%
plot_param_importances(study)
# Out:
# /tmp/ipykernel_44/3836449081.py:1: ExperimentalWarning: optuna.visualization.matplotlib._param_importances.plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   plot_param_importances(study)
# <Axes: title={'left': 'Hyperparameter Importances'}, xlabel='Hyperparameter Importance', ylabel='Hyperparameter'>

# %%
plot_slice(study)
# Out:
# /tmp/ipykernel_44/2457830863.py:1: ExperimentalWarning: optuna.visualization.matplotlib._slice.plot_slice is experimental (supported from v2.2.0). The interface can change in the future.
#   plot_slice(study)
# /usr/local/lib/python3.12/dist-packages/optuna/visualization/matplotlib/_slice.py:153: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(xlim[0], xlim[1])
# array([<Axes: xlabel='alpha', ylabel='Objective Value'>,
#        <Axes: xlabel='booster'>, <Axes: xlabel='colsample_bynode'>,
#        <Axes: xlabel='colsample_bytree'>, <Axes: xlabel='gamma'>,
#        <Axes: xlabel='grow_policy'>,
#        <Axes: xlabel='include_combine_cats'>,
#        <Axes: xlabel='include_decimal'>,
#        <Axes: xlabel='include_features'>, <Axes: xlabel='include_frac'>,
#        <Axes: xlabel='include_freq_encode'>,
#        <Axes: xlabel='include_label_encode'>,
#        <Axes: xlabel='include_target_encode'>, <Axes: xlabel='lambda'>,
#        <Axes: xlabel='learning_rate'>, <Axes: xlabel='max_bin'>,
#        <Axes: xlabel='max_depth'>, <Axes: xlabel='max_leaves'>,
#        <Axes: xlabel='min_child_weight'>, <Axes: xlabel='n_estimators'>,
#        <Axes: xlabel='subsample'>, <Axes: xlabel='target'>,
#        <Axes: xlabel='tree_method'>], dtype=object)
